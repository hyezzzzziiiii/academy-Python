# %%
import cv2
import face_recognition
import pickle
import time
file_name = 'video/son_02.mp4'
encoding_file = 'encodings.pickle'
unknown_name = 'Unknown'
model_method = 'cnn'
output_name = 'video/output_' + model_method + '1.avi'

# %%
def detectAndDisplay(image):
    # 얼굴인식이미지(Face_Recognition_Image) 코드를 참고하여 함수를 제작하세요
    # 이미지 하나당 처리시간계산을 위한 시작시간
    start_time = time.time() 
    # 색상모드 변경
    rgb = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
    # 해당 모델을 이용한 얼굴인식 데이터 추출
    boxes = face_recognition.face_locations(rgb, model=model_method)
    # 추출한 얼굴들의 인코딩
    encodings = face_recognition.face_encodings(rgb, boxes)
    names = [] # 인식된 얼굴들의 이름을 저장할 리스트
    # 인식되서 추출한 얼굴 갯수 만큼 반복실행
    for encoding in encodings:
        # 저장된 인코딩 데이터들과 현재 인식된 얼굴과 비교
        matches = face_recognition.compare_faces(data["encodings"], encoding)
        name = unknown_name
        if True in matches:
            matchedIdxs = [i for (i, b) in enumerate(matches) if b]
            counts = {}
            for i in matchedIdxs:
                name = data["names"][i]
                counts[name] = counts.get(name, 0) + 1
            name = max(counts, key=counts.get)
        names.append(name) # 각 얼굴들에 결정된 이름들 리스트(Unknown, son, tedy)
    # 박스와 이름 표시
    for ((top, right, bottom, left), name) in zip(boxes, names):
        y = top - 15 if top - 15 > 15 else top + 15
        color = (0, 255, 0)
        if(name == unknown_name):
            color = (0, 0, 255)
            name = ''
        cv2.rectangle(image, (left, top), (right, bottom), color, 2)
        cv2.putText(image, name, (left, y), cv2.FONT_HERSHEY_SIMPLEX, 0.75, color, 2)
    end_time = time.time()
    process_time = end_time - start_time
    print("=== A frame took {:.3f} seconds".format(process_time))
    image = cv2.resize(image, None, fx=0.5, fy=0.5)
    cv2.imshow("Recognition", image)
    
    global writer
    if writer is None and output_name is not None:
        fourcc = cv2.VideoWriter_fourcc(*"MJPG")
        writer = cv2.VideoWriter(output_name, fourcc, 24, (image.shape[1], \
                                                      image.shape[0]), True)
    if writer is not None:
        writer.write(image)

# %%
data = pickle.loads(open(encoding_file, "rb").read())
cap = cv2.VideoCapture(file_name)
writer = None
if not cap.isOpened:
    print('--(!)Error opening video capture')
    exit(0)
while True:
    ret, frame = cap.read()
    if frame is None:
        print('--(!) No captured frame -- Break!')
        cap.release()
        writer.release()
        break
    detectAndDisplay(frame)
    if cv2.waitKey(1) & 0xFF == ord('q'):
        break
cv2.destroyAllWindows()
# Out:
# === A frame took 150.977 seconds
# === A frame took 151.039 seconds
# === A frame took 150.066 seconds
# === A frame took 150.195 seconds
# === A frame took 150.755 seconds
# === A frame took 150.868 seconds
# === A frame took 150.903 seconds
# === A frame took 150.297 seconds
# === A frame took 149.890 seconds
# === A frame took 150.810 seconds
# === A frame took 150.039 seconds
# === A frame took 152.547 seconds
# === A frame took 151.835 seconds
# === A frame took 151.818 seconds
# === A frame took 151.113 seconds
# === A frame took 152.353 seconds
# === A frame took 151.732 seconds
# === A frame took 150.700 seconds
# === A frame took 152.394 seconds
# === A frame took 150.809 seconds
# === A frame took 150.768 seconds
# === A frame took 151.005 seconds
# === A frame took 150.473 seconds
# === A frame took 150.725 seconds
# === A frame took 150.424 seconds
# === A frame took 150.871 seconds
# === A frame took 151.579 seconds
# === A frame took 150.838 seconds
# === A frame took 150.837 seconds
# === A frame took 151.050 seconds
# === A frame took 151.093 seconds
# === A frame took 150.391 seconds
# === A frame took 150.424 seconds
# === A frame took 153.198 seconds
# === A frame took 152.254 seconds
# === A frame took 150.178 seconds
# === A frame took 150.951 seconds
# === A frame took 171.173 seconds
# === A frame took 160.487 seconds
# === A frame took 156.660 seconds
# --(!) No captured frame -- Break!
